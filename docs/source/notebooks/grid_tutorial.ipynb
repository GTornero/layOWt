# %% [markdown]
# # Tutorial 1: Generating a `Grid`
#
# LayOWt is a very simple package to use

# %% [markdown]
# ## 1. First step is to import the `grid` object from `layowt.grids`

# %%
from layowt.grids import Grid

# %%
grid = Grid()
grid.plot()
# Out:
# (<Figure size 576x432 with 1 Axes>, <AxesSubplot:>)
